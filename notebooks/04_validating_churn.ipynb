# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.pipeline import apply_pipeline_to_new_data
import joblib, json

# %%
df_clientes_teste = pd.DataFrame([
    # --- CANCELAR (alto risco) ---
    {
        "customerid": "CANCEL-001",
        "tenure": 1,
        "monthlycharges": 99.90,
        "totalcharges": 99.90,
        "total_services": 4,
        "avg_charge_per_service": 24.98,
        "seniorcitizen": 0,
        "automatic_payment": 0,
        "streaming_user": 1,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "New",
        "gender": "Male",
        "partner": "No",
        "dependents": "No",
        "phoneservice": "Yes",
        "multiplelines": "Yes",
        "internetservice": "Fiber optic",
        "contract": "Month-to-month",
        "paperlessbilling": "Yes",
        "paymentmethod": "Electronic check",
        "onlinesecurity": "No",
        "onlinebackup": "No",
        "deviceprotection": "No",
        "techsupport": "No",
        "streamingtv": "Yes",
        "streamingmovies": "Yes",
    },
    {
        "customerid": "CANCEL-002",
        "tenure": 2,
        "monthlycharges": 89.90,
        "totalcharges": 179.80,
        "total_services": 5,
        "avg_charge_per_service": 17.98,
        "seniorcitizen": 0,
        "automatic_payment": 0,
        "streaming_user": 1,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "New",
        "gender": "Female",
        "partner": "No",
        "dependents": "No",
        "phoneservice": "Yes",
        "multiplelines": "No",
        "internetservice": "Fiber optic",
        "contract": "Month-to-month",
        "paperlessbilling": "Yes",
        "paymentmethod": "Electronic check",
        "onlinesecurity": "No",
        "onlinebackup": "Yes",
        "deviceprotection": "No",
        "techsupport": "No",
        "streamingtv": "Yes",
        "streamingmovies": "Yes",
    },
    {
        "customerid": "CANCEL-003",
        "tenure": 3,
        "monthlycharges": 79.90,
        "totalcharges": 239.70,
        "total_services": 3,
        "avg_charge_per_service": 26.63,
        "seniorcitizen": 1,
        "automatic_payment": 0,
        "streaming_user": 0,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "New",
        "gender": "Male",
        "partner": "No",
        "dependents": "No",
        "phoneservice": "Yes",
        "multiplelines": "No",
        "internetservice": "DSL",
        "contract": "Month-to-month",
        "paperlessbilling": "Yes",
        "paymentmethod": "Mailed check",
        "onlinesecurity": "No",
        "onlinebackup": "No",
        "deviceprotection": "No",
        "techsupport": "No",
        "streamingtv": "No",
        "streamingmovies": "No",
    },
    {
        "customerid": "CANCEL-004",
        "tenure": 4,
        "monthlycharges": 94.90,
        "totalcharges": 379.60,
        "total_services": 4,
        "avg_charge_per_service": 23.73,
        "seniorcitizen": 0,
        "automatic_payment": 0,
        "streaming_user": 1,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "Stable",
        "gender": "Female",
        "partner": "No",
        "dependents": "No",
        "phoneservice": "Yes",
        "multiplelines": "Yes",
        "internetservice": "Fiber optic",
        "contract": "Month-to-month",
        "paperlessbilling": "Yes",
        "paymentmethod": "Electronic check",
        "onlinesecurity": "No",
        "onlinebackup": "No",
        "deviceprotection": "Yes",
        "techsupport": "No",
        "streamingtv": "Yes",
        "streamingmovies": "No",
    },

    # --- RETER (baixo risco) ---
    {
        "customerid": "RETER-001",
        "tenure": 72,
        "monthlycharges": 65.00,
        "totalcharges": 4680.00,
        "total_services": 3,
        "avg_charge_per_service": 21.67,
        "seniorcitizen": 0,
        "automatic_payment": 1,
        "streaming_user": 0,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "Loyal",
        "gender": "Male",
        "partner": "Yes",
        "dependents": "Yes",
        "phoneservice": "Yes",
        "multiplelines": "Yes",
        "internetservice": "DSL",
        "contract": "Two year",
        "paperlessbilling": "No",
        "paymentmethod": "Bank transfer (automatic)",
        "onlinesecurity": "Yes",
        "onlinebackup": "Yes",
        "deviceprotection": "Yes",
        "techsupport": "Yes",
        "streamingtv": "No",
        "streamingmovies": "No",
    },
    {
        "customerid": "RETER-002",
        "tenure": 48,
        "monthlycharges": 55.00,
        "totalcharges": 2640.00,
        "total_services": 2,
        "avg_charge_per_service": 27.50,
        "seniorcitizen": 0,
        "automatic_payment": 1,
        "streaming_user": 0,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "Stable",
        "gender": "Female",
        "partner": "Yes",
        "dependents": "No",
        "phoneservice": "Yes",
        "multiplelines": "No",
        "internetservice": "DSL",
        "contract": "One year",
        "paperlessbilling": "No",
        "paymentmethod": "Credit card (automatic)",
        "onlinesecurity": "Yes",
        "onlinebackup": "No",
        "deviceprotection": "No",
        "techsupport": "Yes",
        "streamingtv": "No",
        "streamingmovies": "No",
    },
    {
        "customerid": "RETER-003",
        "tenure": 60,
        "monthlycharges": 85.00,
        "totalcharges": 5100.00,
        "total_services": 5,
        "avg_charge_per_service": 17.00,
        "seniorcitizen": 1,
        "automatic_payment": 1,
        "streaming_user": 1,
        "internet_and_phone": 1,
        "customer_lifecycle_stage": "Loyal",
        "gender": "Male",
        "partner": "Yes",
        "dependents": "Yes",
        "phoneservice": "Yes",
        "multiplelines": "Yes",
        "internetservice": "Fiber optic",
        "contract": "Two year",
        "paperlessbilling": "Yes",
        "paymentmethod": "Credit card (automatic)",
        "onlinesecurity": "Yes",
        "onlinebackup": "Yes",
        "deviceprotection": "Yes",
        "techsupport": "Yes",
        "streamingtv": "Yes",
        "streamingmovies": "Yes",
    },
    {
        "customerid": "RETER-004",
        "tenure": 36,
        "monthlycharges": 25.00,
        "totalcharges": 900.00,
        "total_services": 1,
        "avg_charge_per_service": 25.00,
        "seniorcitizen": 0,
        "automatic_payment": 1,
        "streaming_user": 0,
        "internet_and_phone": 0,
        "customer_lifecycle_stage": "Stable",
        "gender": "Female",
        "partner": "Yes",
        "dependents": "Yes",
        "phoneservice": "Yes",
        "multiplelines": "No",
        "internetservice": "No",
        "contract": "One year",
        "paperlessbilling": "No",
        "paymentmethod": "Bank transfer (automatic)",
        "onlinesecurity": "No",
        "onlinebackup": "No",
        "deviceprotection": "No",
        "techsupport": "No",
        "streamingtv": "No",
        "streamingmovies": "No",
    },
])

# %%
pipe = joblib.load("../model/churn_pipeline.pkl")
with open("../model/churn_params.json", "r") as f:
    churn_params = json.load(f)

# %%
apply_pipeline_to_new_data(df_clientes_teste, pipe, churn_params)
# Out:
#    tenure  monthlycharges  totalcharges  total_services  \
# 0       1            99.9          99.9               4
# 1       2            89.9         179.8               5
# 2       3            79.9         239.7               3
# 3       4            94.9         379.6               4
# 4      72            65.0        4680.0               3
# 5      48            55.0        2640.0               2
# 6      60            85.0        5100.0               5
# 7      36            25.0         900.0               1
#
#    avg_charge_per_service  seniorcitizen  automatic_payment  streaming_user  \
# 0                   24.98              0                  0               1
# 1                   17.98              0                  0               1
# 2                   26.63              1                  0               0
# 3                   23.73              0                  0               1
# 4                   21.67              0                  1               0
# ...
